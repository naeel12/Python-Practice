# %%
x=10
y="Nail"
print (x)
print (y)
a=str (3)
b=int (3)
c=float (3)
print(a)
print(b)
print(c)
# Out:
# 10
# Nail
# 3
# 3
# 3.0

# %%
n="Nail"
print(n)

m='Nail'
print(m)
# Out:
# Nail
# Nail

# %%
a = f = z = 'bluebarry'
print(a)
print(f)
print(z)
i,h,k="apple","orange","kiwi"
print(i)
print(h)
print(k)
# Out:
# bluebarry
# bluebarry
# bluebarry
# apple
# orange
# kiwi

# %%
x=12
y="Nail"
print(x,y)
# Out:
# 12 Nail

# %%
x="phython"

def myfunc():
  print("i am defined as gloabal but used in function body" + x)

# %%
x = "global"

def myfunc():
    x = "Local"
    print("This is " + x)

myfunc()

print("This is " + x)
# Out:
# This is Local
# This is global

# %%
def myfunc():
    global x
    x = "Fun"

myfunc()

print("Python is " + x)
# Out:
# Python is Fun

# %%
x = "fun"

def myfunc():
    global x
    x = "joy"

myfunc()

print("Python is " + x)
# Out:
# Python is joy

# %%
if 10 > 7:
  print("Ten is greater than seven")
# Out:
# Ten is greater than seven

# %%
t1 = "Hello Class"
t2 = str("Again Hello Class")

print(t1)
print(t2)

print(type(t1))
print(type(t2))
# Out:
# Hello Class
# Again Hello Class
# <class 'str'>
# <class 'str'>

# %%
h1 = 7.89
h2 = float(44.6)
h3 = -56.9
h4 = 3e5
h5 = 56.9
h6 = -67.9


print(h1)
print(h2)
print(h3)
print(h4)
print(h5)
print(h6)


print(type(h1))
print(type(h2))
print(type(h3))
print(type(h4))
print(type(h5))
print(type(h6))
# Out:
# 7.89
# 44.6
# -56.9
# 300000.0
# 56.9
# -67.9
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
e1 = 1j
e2 = complex(5j)
e3 = 4+6j
e4 = -4j


print(e1)
print(e2)
print(e3)
print(e4)

print(type(e1))
print(type(e2))
print(type(e3))
print(type(e4))
# Out:
# 1j
# 5j
# (4+6j)
# (-0-4j)
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %%
j1 = ["kiwi", "banana", "cherry"]
l2 = list(("apple", "bluebarry", "cherry"))

print(j1)
print(l2)


print(type(j1))
print(type(l2))
# Out:
# ['kiwi', 'banana', 'cherry']
# ['apple', 'bluebarry', 'cherry']
# <class 'list'>
# <class 'list'>

# %%
r1=range(5)
print(r1)
print(type(r1))
# Out:
# range(0, 5)
# <class 'range'>

# %%
p1 = {"name" : "Nail", "age" : 22}
d2 = dict(name="Nail", age=22)

print(p1)
print(d2)

print(type(p1))
print(type(d2))
# Out:
# {'name': 'Nail', 'age': 22}
# {'name': 'Nail', 'age': 22}
# <class 'dict'>
# <class 'dict'>

# %%
set1 = {"cherry", "banana", "cherry"}
set2 = set(("cherry", "banana", "cherry"))


print(set1)
print(set2)

print(type(set1))
print(type(set2))
# Out:
# {'banana', 'cherry'}
# {'banana', 'cherry'}
# <class 'set'>
# <class 'set'>

# %%
fset = frozenset(("gava", "banana", "cherry"))
print(fset)
print(type(fset))
# Out:
# frozenset({'gava', 'banana', 'cherry'})
# <class 'frozenset'>

# %%
a1 = False
a2 = bool(5)
print(a1)
print(a2)
print(type(a1))
print(type(a2))
# Out:
# False
# True
# <class 'bool'>
# <class 'bool'>

# %%
ba = bytearray(5)
print(ba)

print(type(ba))
# Out:
# bytearray(b'\x00\x00\x00\x00\x00')
# <class 'bytearray'>

# %%
n = None
print(n)
print(type(n))
# Out:
# None
# <class 'NoneType'>

# %%
i1 = 25
f1 = float(i1)
f2 = float("3")
f3 = float("4.2")
print(f1)
print(f2)
print(f3)
f4 = 29.5
i2 = int(f4)
i3 = int("3")
print(i2)
print(i3)
s1 = str(2)
s2 = str(3.0)
print(s1)
print(s2)
print(type(s1))
print(type(s2))
z = complex(i1)
# Out:
# 25.0
# 3.0
# 4.2
# 29
# 3
# 2
# 3.0
# <class 'str'>
# <class 'str'>

# %%
a = "Nail"
b = "Ramzan"

print(a)
print(b)

for x in a:
    print(x)

if "Asif" in a:
    print("Nail is present in string a")
else:
    print("Nail is not present")

if "Nail" not in a:
    print("Nail is not present in string a")
else:
    print("Nail is present in string a")
# Out:
# Nail
# Ramzan
# N
# a
# i
# l
# Nail is not present
# Nail is present in string a

# %%
a = "Nail"
print(a[1])

print(len(a))

c = """Lorem ipsum dolor sit amet,
consectetur adipisicing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua."""
print(c)

d = '''Lorem ipsum dolor sit amet,
consectetur adipisicing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua.'''
print(d)
# Out:
# a
# 4
# Lorem ipsum dolor sit amet,
# consectetur adipisicing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.
# Lorem ipsum dolor sit amet,
# consectetur adipisicing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.

# %%
myName = "Nail"

print(myName[9:13])

print(myName[9:])

print(myName[:9])
# Out:
# Nail

# %%
myName="Nail Ramzan"
print (myName[-7:-1])
# Out:
#  Ramza

# %%
myName = "Nail Ramzan"
print(myName.upper())
print(myName.lower())
print(myName.strip())
print(myName.replace("s", "R"))
print(myName.split(" "))
salutation = "Mr. "
completeName = salutation + myName
print(completeName)
# Out:
# NAIL RAMZAN
# nail ramzan
# Nail Ramzan
# Nail Ramzan
# ['Nail', 'Ramzan']
# Mr. Nail Ramzan

# %%
escapeText = "Hard work is key to success, \"Nail Ramzan\" ."
print(escapeText)
escapeText = 'Asif\'s Laptop.'
print(escapeText)
escapeText = "I am going to insert one backslash \\ here."
print(escapeText)
escapeText = "Muhammad\nNail \n Ramzan"
print(escapeText)
escapeText = "Muhammad\rNail \rRamzan"
print(escapeText)
escapeText = "Muhammad\tNail \t Ramzan"
print(escapeText)
escapeText = "Muhammad \bNail  \b Ramzan"
print(escapeText)
escapeText = "\110\145\154\154\157"
print(escapeText)
escapeText = "\x48\x65\x6c\x6c\x6f"
print(escapeText)
# Out:
# Hard work is key to success, "Nail Ramzan" .
# Asif's Laptop.
# I am going to insert one backslash \ here.
# Muhammad
# Nail
#  Ramzan
# Ramzan
# Muhammad	Nail 	 Ramzan
#  Ramzan
# Hello
# Hello

# %%
print(20 > 19)
print(20 == 19)
print(20 < 19)
x = 139
y = 23
z = 500

if x > y:
  print("x is greater than y")
else:
  print("x is not greater than y")

if x > 100:
  print("Above Hundred,")
  if x > 200:
    print("and also above 200!")
  else:
    print("but not above 200.")
# Out:
# True
# False
# False
# x is greater than y
# Above Hundred,
# but not above 200.

# %%
y = 26
z = 400
if y > x:
    print("y is greater than x")
elif y == x:
    print("x and y are equal")

x = 140
if y > x:
    print("y is greater than x")
elif x == y:
    print("x and y are equal")
else:
    print("x is greater than y")

if x > y or x > z:
    print("At least one of the conditions is True")

if x > y and z > x:
    print("Both conditions are True")

if y > x:
    pass
# Out:
# x is greater than y
# At least one of the conditions is True
# Both conditions are True

# %%
print(bool("Nail Ramzan"))
print(bool(4789))
print(bool(["Osama", "Ahmad", "Ahmar"]))

x = "Nail Ramzan"
y = 4789
print(bool(x))
print(bool(y))

print(bool(False))
print(bool(None))
print(bool(0))
print(bool(""))
print(bool(()))
print(bool([]))
print(bool({}))
# Out:
# True
# True
# True
# True
# True
# False
# False
# False
# False
# False
# False
# False

# %%
class myclass():
  def __len__(self):
    return 0

myobj = myclass()
print(bool(myobj))
# Out:
# False

# %%
x = 132
y = 53
z = 400

if x > y: print("x is greater than y")

print("X") if x > y else print("Y")

print("X") if x > y else print("X equals Y") if x == y else print("Y")
# Out:
# x is greater than y
# X
# X

# %%
a = "Nail"
b = 'Ramzan'
print(a)
print(b)

for x in a:
    print(x)

if "Nail Ramzan" in a:
    print("Nail Ramzan is present in string a")
else:
    print("Nail Ramzan is not present")

if "Ali" not in a:
    print("Nail Ramzan is not present in string a")
else:
    print("Nail Ramzan is present in string a")
# Out:
# Nail
# Ramzan
# N
# a
# i
# l
# Nail Ramzan is not present
# Nail Ramzan is not present in string a

# %%
def myFunction() :
  return True

if myFunction():
  print("YES!")
else:
  print("NO!")

w = 200
print(isinstance(w, int))
# Out:
# YES!
# True

# %%
x = 5
print(x)

x += 3
print(x)

x -= 3
print(x)

x *= 3
print(x)

x /= 3
print(x)

x %= 3
print(x)

x = 5
x //= 3
print(x)

x = 5
x **= 3
print(x)
# Out:
# 5
# 8
# 5
# 15
# 5.0
# 2.0
# 1
# 125

# %%
x = 5
print(x)

x += 3
print(x)

x -= 3
print(x)

x *= 3
print(x)

x /= 3
print(x)

x %= 3
print(x)

x = 5
x //= 3
print(x)

x = 5
x **= 3
print(x)
# Out:
# 5
# 8
# 5
# 15
# 5.0
# 2.0
# 1
# 125

# %%
x = 5
x &= 3
print(x)

x = 5
x |= 3
print(x)

x = 5
x ^= 3
print(x)

x = 5
x >>= 3
print(x)

x = 5
x <<= 3
print(x)
# Out:
# 1
# 7
# 6
# 0
# 40

# %%
x = b"Hyyyy"

print(x)
print(type(x))
# Out:
# b'Hyyyy'
# <class 'bytes'>

# %%
x = {"Name" : "Ahsan", "age" : 36}
print(x)

print(type(x))

y = frozenset(x)

print(y)

print(type(y))
# Out:
# {'Name': 'Ahsan', 'age': 36}
# <class 'dict'>
# frozenset({'Name', 'age'})
# <class 'frozenset'>

# %%
t1 = ("kiwi", "banana", "cherry")

print(t1)

print(type(t1))
# Out:
# ('kiwi', 'banana', 'cherry')
# <class 'tuple'>

# %%
list1 = ["Orange", "banana", "cherry"]

print(list1)

print(type(list1))


print(len(list1))
# Out:
# ['Orange', 'banana', 'cherry']
# <class 'list'>
# 3
